# %%
print("hello babes")
# Out:
# hello babes

# %%
print(2+3)
# Out:
# 5

# %%
a = 2
b = 3
c = a + b

# %%
print(c)
# Out:
# 5

# %%
c = 6
print(c)
# Out:
# 6

# %%
a = 3
c = a + b
print(c)
# Out:
# 6
